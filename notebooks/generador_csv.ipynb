# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# Semilla fija para consistencia en el equipo de desarrollo
np.random.seed(2026)

print("Generando archivos CSV basados en el diagrama relacional...")

# -------------------------------------------------------------------------
# TABLA 1: productos.csv
# -------------------------------------------------------------------------
productos_data = {
    'producto_id': ['PROD-01', 'PROD-02', 'PROD-03', 'PROD-04', 'PROD-05', 'PROD-06', 'PROD-07', 'PROD-08'],
    'nombre': [
        'Cómic Oficial Vol 1 (Físico)', 
        'Cómic Oficial Vol 1 (Virtual)', 
        'Peluche Personaje Coleccionable', 
        'Botella de Agua TDAH', 
        'Mochila Ergonómica', 
        'Lapicera Colección', 
        'Libreta de Tareas', 
        'Planilla Stickers'
    ],
    'categoria': ['Lectura', 'Lectura', 'Peluches', 'Accesorios', 'Accesorios', 'Papelería', 'Papelería', 'Papelería'],
    'precio': [150.00, 80.00, 280.00, 120.00, 450.00, 95.00, 110.00, 35.00],
    'costo': [45.00, 5.00, 90.00, 35.00, 180.00, 25.00, 30.00, 8.00]
}
df_productos = pd.DataFrame(productos_data)
df_productos.to_csv('productos.csv', index=False)
print("- 'productos.csv' creado con éxito.")

# -------------------------------------------------------------------------
# TABLA 2: ubicaciones.csv (190 coordenadas de Puebla)
# -------------------------------------------------------------------------
coordenadas_fuente = {
    'Xicotepec de Juárez': [
        (20.284964366428074, -97.95489225438446), (20.2823478518014, -97.96550307333979),
        (20.2768731552715, -97.95925889059241), (20.272545592784184, -97.96728405997214),
        (20.267550923885214, -97.96922806008055), (20.261814016908424, -97.96433571087877),
        (20.26326336073004, -97.9686272452115), (20.268108133121515, -97.9726818655338),
        (20.275854028568954, -97.95344261674958), (20.277981323967843, -97.96190618536343)
    ],
    'Huauchinango': [
        (20.18502866253168, -98.06157979846837), (20.184384187262154, -98.05737409462476),
        (20.180517279683475, -98.04544362861948), (20.174394479847273, -98.04578695138223),
        (20.168674278579942, -98.0423537237548), (20.159569863692276, -98.04484281378467),
        (20.16770746327491, -98.05462751252284), (20.172944307828807, -98.04819021072142),
        (20.17955053780023, -98.0458727820729), (20.17890603988084, -98.07119283582516),
        (20.170607891212935, -98.06904706855802), (20.175764074370818, -98.0799475662751),
        (20.17818097653682, -98.06346807366347), (20.178261539297125, -98.04552945931016),
        (20.172702611181343, -98.0608073222522)
    ],
    'Tehuacán': [
        (18.4304065809675, -97.37363463856055), (18.43626931791577, -97.3780978344762),
        (18.44294608031644, -97.36985808817037), (18.443597457880003, -97.38238936901047),
        (18.443271769406934, -97.38908416288396), (18.449459744808042, -97.38050109381538),
        (18.449622583255515, -97.38204604624774), (18.45939260751467, -97.37912780276442),
        (18.46036957936015, -97.38650924216338), (18.467731048165322, -97.37792617309482),
        (18.468999255778982, -97.38118773934087), (18.493257718018807, -97.39217406774864),
        (18.481861552559202, -97.39148742222315), (18.47958222853272, -97.43148452408263),
        (18.45695015357284, -97.41775161357295), (18.454507664879735, -97.41775161357295),
        (18.448645550254735, -97.4108851583181), (18.46785951207198, -97.4096835286485),
        (18.46036957936015, -97.39646560228292), (18.46150937281795, -97.39406234294373),
        (18.460858063197513, -97.38736754907023), (18.448645550254735, -97.3846209669683),
        (18.493420514891252, -97.46341354101769), (18.495211271059148, -97.4642718469481),
        (18.502374105369224, -97.41208678701125), (18.497002007723047, -97.43697768731009),
        (18.47893098831278, -97.43182784586894), (18.472092808451556, -97.43251449139443),
        (18.473395339246665, -97.39183074599316)
    ],
    'Zacatlán': [
        (19.92499117719992, -97.96852730635536), (19.938385618481306, -97.96320580353284),
        (19.94048344015599, -97.95153282959961), (19.943710803704, -97.9391732101409),
        (19.9482290018512, -97.96166085110052), (19.963880331050074, -97.95651100965938),
        (19.961298775424904, -97.96972893602496), (19.945001730654027, -97.93608330527621),
        (19.93451264372708, -97.97058724293183), (19.94016070017357, -97.96166085110052)
    ],
    'Atlixco': [
        (18.918064363185692, -98.41526164390673), (18.8617059702976, -98.44564570840943),
        (18.916765247952736, -98.42126979225472), (18.9122182651453, -98.44324244907024),
        (18.90426074775045, -98.44375743321434), (18.895328389622563, -98.43723430072225),
        (18.90880794690279, -98.44392909459573), (18.93073020755921, -98.45766200510542),
        (18.92114972140276, -98.4595502803005), (18.91627807713782, -98.41809405669936),
        (18.918064363185717, -98.45817698924952), (18.90166229253208, -98.40582026891211),
        (18.90052545577758, -98.40633525305623), (18.853502375141833, -98.47190989961776),
        (18.91476859302664, -98.47821013066654), (18.93027630720187, -98.45803991835541),
        (18.915255768239838, -98.47889677619203), (18.918016400968153, -98.45726744213925),
        (18.912982271472533, -98.42465178056229), (18.91663609000686, -98.41581121942168),
        (18.935472287545135, -98.40139166337109), (18.934092121065007, -98.39847341988778),
        (18.92337514625093, -98.42705503988608), (18.90080230025062, -98.43958632072618)
    ],
    'San Andrés Cholula': [
        (19.0150490611301, -98.31244148884034), (19.052229119336353, -98.2981835000677),
        (19.0165978317972, -98.29862292983948), (19.01318964762994, -98.30875095153036),
        (19.046781554743713, -98.27493366030588), (19.05035130949694, -98.2917564747746),
        (19.0462947638834, -98.29810794569538), (19.0498645292596, -98.29639133207162),
        (19.02846632074024, -98.30595361361358), (19.028327611983883, -98.30758674106724),
        (19.02254395739461, -98.31383855705774), (19.03720473808938, -98.30796950531442),
        (19.045970235953778, -98.27527698216296), (19.032006369923756, -98.3067000039147),
        (19.027827053389142, -98.30837140779035), (19.0498645292596, -98.29089816786774),
        (19.034828705995185, -98.3070253535229), (19.02909390922756, -98.30857929014898),
        (19.020288337830102, -98.31577151651315), (19.026168565302246, -98.3109550664127),
        (19.025770525707348, -98.31128679543386), (19.02428088417428, -98.31352596624933),
        (19.011566678229418, -98.30772098305215), (19.020963820680514, -98.31583531055568),
        (19.026497399053145, -98.32282718480278), (19.023991397638422, -98.31374286599394),
        (19.020107404433713, -98.317251538278), (19.019169267718645, -98.31783351860172),
        (19.023502887965606, -98.31386407467475), (19.01946810496396, -98.31509529966233),
        (19.02112062880673, -98.31609048672581), (19.021566928048514, -98.3172196412786),
        (19.02134980964816, -98.31721326187434), (19.022682670933907, -98.31760878490336),
        (19.021452337817006, -98.31708567378928), (19.01239350915052, -98.31493673287773),
        (19.020595924111344, -98.31704739736377), (19.020987945017257, -98.31726429710838),
        (19.018580964302764, -98.31794080696505), (19.016694322033104, -98.31540880167651),
        (19.01732320515911, -98.31362781484478), (19.02247761605101, -98.31867414541362),
        (19.0146656506021, -98.32010803190488), (19.017120339923522, -98.31877765619926),
        (19.0214643999747, -98.31806810200959), (19.017566643178824, -98.31663188893212),
        (19.017810080813025, -98.31781206092903), (19.019570634269705, -98.31785120227777),
        (19.018756429026666, -98.3175768878949)
    ],
    'Puebla (Centro)': [
        (18.962541425145318, -98.27158942774984), (19.06770342553383, -98.17543123127385),
        (18.964016118157563, -98.25183801441963), (19.091282020368375, -98.17647077934386),
        (19.07949314246757, -98.13904704882347), (18.9694232142765, -98.22065157231931),
        (19.108472629070302, -98.22844818284439), (19.010707979772057, -98.20349902916413),
        (19.022993134592785, -98.19674196670907), (19.057878020811533, -98.22065157231931),
        (19.012673665548657, -98.23520524529945), (19.059843148924525, -98.2201317990469),
        (19.060825703360525, -98.19206400039403), (19.054438991624078, -98.23780411547449),
        (19.07998436304104, -98.13177021451399), (19.06770342553383, -98.20090015898911),
        (19.027906942847956, -98.14424479135411), (19.009233700783795, -98.2024594818567),
        (19.04657808577291, -98.16347642846873), (19.06573839174284, -98.19726174292465)
    ],
    'Puebla (San Andrés Azumiatla)': [
        (18.901294484607757, -98.25925244385704), (18.903075740814074, -98.25745931103285),
        (18.906638196336388, -98.24598326095801), (18.903075740814074, -98.25297647897236),
        (18.903415025560566, -98.25467995515534), (18.899428386340055, -98.24939021332398),
        (18.90265163391346, -98.25826622080375), (18.88941895873616, -98.26023866691034),
        (18.899428386340055, -98.24939021332398), (18.890191792692024, -98.25082471958333),
        (18.897816739272187, -98.25952141378066)
    ],
    'Puebla (La Paz Tlaxcolpan)': [
        (18.89960385027817, -98.22233381020449), (18.9038872720808, -98.2243508314356),
        (18.905044386179313, -98.2250803922242), (18.904942885256602, -98.22308482874799),
        (18.90254744576637, -98.22136821493427), (18.904130875737184, -98.22216214888282),
        (18.900781294687047, -98.22160424933368), (18.900639189766956, -98.22160424933368)
    ],
    'Cuautlancingo (San Lorenzo Almecatla)': [
        (19.15489279419337, -98.23223763767818), (19.15440632145918, -98.24073487605604),
        (19.154244163562293, -98.24356728884867), (19.155541422273828, -98.2415931829629),
        (19.155379265379402, -98.24013406126755), (19.15400092630465, -98.23918992367001),
        (19.154892794079938, -98.23180848427106), (19.1364869095899, -98.23343926739409),
        (19.15108205271274, -98.23867493947961), (19.152055016352747, -98.24270898194183),
        (19.13762213377546, -98.23901826224234), (19.13924386879345, -98.24957543695139),
        (19.145325233776628, -98.2362716801404), (19.142000781961723, -98.2585018287827),
        (19.141189929926924, -98.25532609322732), (19.13494623586544, -98.2327526218686),
        (19.14483873271919, -98.22751694973678), (19.149136108105868, -98.23635751087738)
    ],
    'Amozoc de Mota': [
        (19.0492348540696, -98.07535326619758), (19.034557043718344, -98.07443463186864),
        (19.048101199294088, -98.0705942306248), (19.04570928088288, -98.06510339026235),
        (19.04898159144052, -98.07434532032558), (19.048885110337302, -98.07548085428263),
        (19.03101101824674, -98.07522567799602), (19.040545979619587, -98.0573955744083),
        (19.038464820826707, -98.07272495152884), (19.04288111909371, -98.07729487818023),
        (19.04783192481297, -98.05338993782273), (19.037524068075708, -98.07964022573913),
        (19.045315108831325, -98.05017238039187), (19.03914893321776, -98.05274730111245),
        (19.065272474591495, -98.04605250723897), (19.044341517383312, -98.03798442231452),
        (19.049533939108677, -98.04725413690856), (19.049371678388948, -98.03918605198412),
        (19.026166762374597, -98.02837138495774), (19.04353018681422, -98.03695445402627),
        (19.030710637591085, -98.0350661788312), (19.042718852279442, -98.02682643252538)
    ],
    'Villa Avila Camacho': [
        (20.395240362988524, -97.883882462417), (20.39041328487738, -97.88195127187659),
        (20.39109713013461, -97.87521356265776), (20.379994326090664, -97.88092130358835),
        (20.38321261244506, -97.88285249412878), (20.383091927918866, -97.8795480125374)
    ],
    'Chignahuapan': [
        (19.830745875895033, -98.03659625745681), (19.843323679538585, -98.03317689676142),
        (19.832810240209984, -98.03705557456304), (19.835450667319225, -98.04272048537685),
        (19.83535465248198, -98.0379742087597), (19.844427790296898, -98.02669542204029),
        (19.83583590938461, -98.03426808454599), (19.836362804504848, -98.0383824906319),
        (19.8383854302683, -98.04206960903007), (19.837803010437845, -98.02623610494986),
        (19.83713091589475, -98.02353123754655), (19.833674384749003, -98.03669832792485),
        (19.83295426462626, -98.0290430428212), (19.834442509281732, -98.03108445218217),
        (19.834778562596803, -98.02894097235315), (19.831850074097943, -98.02317399090839),
        (19.833722392641114, -98.02026498256897), (19.83295426462626, -98.02924718375729),
        (19.83641081144245, -98.01847874937812), (19.829545651752873, -98.01766218563374),
        (19.835786718276207, -98.01454903635826), (19.82455262201839, -98.02710370392826),
        (19.82407251473809, -98.02863476094899)
    ],
    'San Antonio Matlahuacales': [
        (19.757575526206143, -98.079388839317), (19.75743416473398, -98.08116982614872),
        (19.75379911242499, -98.08550427602835), (19.75767649860954, -98.07966778906172),
        (19.754364570446285, -98.08288643996242)
    ],
    'Heroica Puebla de Zaragoza': [
        (18.95038997713883, -98.24289987441004), (18.950936079090397, -98.24852950232287),
        (18.95448569820932, -98.25156084042979), (18.958581318730882, -98.2647688136099),
        (18.96028779760123, -98.26448011474257), (18.957489163090955, -98.27097583925739),
        (18.96383721771913, -98.27213063472668), (18.969638991752745, -98.27335760491282),
        (18.949024714440988, -98.2234127008656), (18.960765608556, -98.21958744087355),
        (18.963427673099748, -98.21836047068741), (18.961926000889537, -98.2395798374358),
        (18.962199033206335, -98.24795210458822), (18.965816669198574, -98.25480870268719),
        (18.968615163948076, -98.25899483626338), (18.972027898840928, -98.26245922267128),
        (18.969502481742122, -98.26794450115047), (18.975235806072035, -98.27047061637664),
        (18.98506390301563, -98.26729492882036), (18.984381415030644, -98.25314868432146),
        (18.974143759691806, -98.23402238436118), (18.976464350039254, -98.25278781073729),
        (18.971823137028533, -98.25913918581844), (18.992693207836556, -98.2306980755512),
        (18.983957550633328, -98.21460311369785), (18.984025799731366, -98.20370473145633),
        (18.996241937648115, -98.19071328242671), (19.005113431117763, -98.19699248279103),
        (19.02046682128743, -98.22326407986034), (19.031315695241986, -98.21481963772132),
        (19.04222968175412, -98.18887783125028), (19.055997988468274, -98.1675144370996),
        (19.075845285852765, -98.17965272923065), (19.078827911564364, -98.19555389228725),
        (19.084563578688144, -98.22735621767063), (19.08123691613343, -98.25211833440542),
        (19.073092046030165, -98.25321078069722), (19.121478555274138, -98.22252203203323),
        (19.110124854149614, -98.20363928094186)
    ]
}

ubicaciones_lista = []
id_cont = 1

for municipio, coords in coordenadas_fuente.items():
    for lat, lon in coords:
        ubicaciones_lista.append({
            'ubicacion_id': f'UBI-PUE{str(id_cont).zfill(3)}',
            'estado': 'Puebla',
            'municipio': municipio,
            'latitud': lat,
            'longitud': lon
        })
        id_cont += 1

df_ubicaciones = pd.DataFrame(ubicaciones_lista)
df_ubicaciones.to_csv('ubicaciones.csv', index=False)
print(f"- 'ubicaciones.csv' creado con {len(df_ubicaciones)} puntos geográficos mapeados.")

# -------------------------------------------------------------------------
# TABLA 3: jugadores.csv
# -------------------------------------------------------------------------
n_jugadores = 250
inicio_proyecto = datetime(2023, 1, 1)
jugadores_lista = []

for i in range(1, n_jugadores + 1):
    dias_registro = np.random.randint(0, 1000)
    jugadores_lista.append({
        'jugador_id': f'JUG-{str(i).zfill(3)}',
        'fecha_registro': (inicio_proyecto + timedelta(days=dias_registro)).strftime('%Y-%m-%d'),
        'edad_nino': np.random.randint(6, 13),
        'tipo_suscripcion': np.random.choice(['Gratuita', 'Premium'], p=[0.75, 0.25])
    })
df_jugadores = pd.DataFrame(jugadores_lista)
df_jugadores.to_csv('jugadores.csv', index=False)
print("- 'jugadores.csv' creado con éxito.")

# -------------------------------------------------------------------------
# TABLA 4: ventas_sucias.csv (Columna de canal eliminada)
# -------------------------------------------------------------------------
n_pedidos = 2300
ventas_lista = []
id_renglon_control = 1
total_ubicaciones = len(df_ubicaciones)

for i in range(1, n_pedidos + 1):
    venta_id = 50000 + i
    
    jugador_idx = np.random.randint(0, n_jugadores)
    jugador_id = df_jugadores.iloc[jugador_idx]['jugador_id']
    fecha_reg = datetime.strptime(df_jugadores.iloc[jugador_idx]['fecha_registro'], '%Y-%m-%d')
    
    fin_simulacion = datetime(2026, 12, 31)
    dias_maximos = (fin_simulacion - fecha_reg).days
    
    if dias_maximos <= 0:
        fecha_venta_dt = fecha_reg
    else:
        fecha_venta_dt = fecha_reg + timedelta(days=np.random.randint(0, min(dias_maximos, 500)))
        
    fecha_venta = fecha_venta_dt.strftime('%Y-%m-%d')
    
    ubi_idx = np.random.randint(0, total_ubicaciones)
    ubicacion_id = df_ubicaciones.iloc[ubi_idx]['ubicacion_id']
    
    for _ in range(np.random.choice([1, 2, 3], p=[0.65, 0.25, 0.10])):
        prod_idx = np.random.randint(0, len(df_productos))
        producto_id = df_productos.iloc[prod_idx]['producto_id']
        
        cantidad = float(np.random.choice([1, 2, 3], p=[0.80, 0.15, 0.05]))
        
        ventas_lista.append({
            'id_renglon': id_renglon_control,
            'venta_id': venta_id,
            'fecha_venta': fecha_venta,
            'jugador_id': jugador_id,
            'producto_id': producto_id,
            'ubicacion_id': ubicacion_id,
            'cantidad': cantidad
        })
        id_renglon_control += 1

df_ventas = pd.DataFrame(ventas_lista)

# NUEVA LÓGICA DE DATOS SUCIOS PARA EL RETO ETL (Aplicada a la cantidad)
# 1. Metemos algunos nulos (NaN)
df_ventas.loc[df_ventas.sample(frac=0.01).index, 'cantidad'] = np.nan
# 2. Metemos algunas compras con cantidad "0" o negativas que no deberían existir
df_ventas.loc[df_ventas.sample(frac=0.01).index, 'cantidad'] = 0

df_ventas.to_csv('ventas_sucias.csv', index=False)
print(f"- 'ventas_sucias.csv' creado con {len(df_ventas)} registros históricos (Limpieza de canales lista).")
print("\n¡Catálogo y estructura simplificados con éxito!")
# Out:
# Generando archivos CSV basados en el diagrama relacional...
# - 'productos.csv' creado con éxito.
# - 'ubicaciones.csv' creado con 289 puntos geográficos mapeados.
# - 'jugadores.csv' creado con éxito.
# - 'ventas_sucias.csv' creado con 3379 registros históricos (Limpieza de canales lista).
#
# ¡Catálogo y estructura simplificados con éxito!
